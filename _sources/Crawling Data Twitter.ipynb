# %% [markdown]
# ## CRAWLING DATA TWITTER

# %%
pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.5.0.20230113-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.26.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.5.0.20230113

# %%
import pandas as pd
from tqdm.notebook import tqdm
from ipywidgets import FloatProgress
import snscrape.modules.twitter as sntwitter

# %%
scraper=sntwitter.TwitterSearchScraper("ridwankamil")
tweets=[]
n_tweets=500
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
    data=[
        tweet.user.username, 
        tweet.rawContent, 
        tweet.user.location,
    ]
    tweets.append(data)
    if i > n_tweets:
        break
tweet_df=pd.DataFrame(tweets, columns=['@Username','Tweet', 'Lokasi']
            )
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
tweet_df
# Out:
#            @Username                                              Tweet  \
# 0            kafi_kh  @humasjabar @elkhoers_ID @ridwankamil @ESDMJab...
# 1          arieza023  @kifnitaufik @humasjabar @ridwankamil @ESDMJab...
# 2         SobriIndra  Gubernur Jawa Barat @ridwankamil menyebutkan, ...
# 3         SobriIndra  Gubernur Jawa Barat @ridwankamil berencana mel...
# 4         SobriIndra  Gubernur Jawa Barat @ridwankamil mengemukakan ...
# ..               ...                                                ...
# 497  perekonomianjbr  Last but not least! Ada Pak Sekda Provinsi Jaw...
# 498         fuckhsya  @humasjabar @ridwankamil @ESDMJabar SKIP, GABI...
# 499       Dazzzzzaii  @evildance_ @Outstandjing @ridwankamil Masjid ...
# 500      ikromzzzzzt  @humasjabar @ridwankamil @ESDMJabar Ayo naik m...
# 501  perekonomianjbr  Ga cuma dengerin narasumber ajaaa, ada juga ac...
#
#                  Lokasi
# 0
# 1
# 2    Bandung, Indonesia
# 3    Bandung, Indonesia
# 4    Bandung, Indonesia
# ..                  ...
# 497             Bandung
# 498           stay away
# 499
# 500           Di hatimu
# 501             Bandung
#
# [502 rows x 3 columns]

# %%
tweet_df.to_csv('ridwankamil.csv', index=False)
