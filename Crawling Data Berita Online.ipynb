# %%
import requests as req
from bs4 import BeautifulSoup as bs
from datetime import datetime
import csv
hades = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'}

# %%
def scrape_detik(hal):
    global hades
    a = 1
    for page in range(1,hal):
        url = f'https://www.detik.com/search/searchnews?query=pemilu+2024&sortby=time&page={page}'
        ge = req.get(url,hades).text
        sop = bs(ge,'lxml')
        li = sop.find('div',class_='list media_rows list-berita')
        lin = li.find_all('article')
        for x in lin:
            link = x.find('a')['href']
            date = x.find('a').find('span',class_='date').text.replace('WIB','').replace('detikNews','').split(',')[1]
            headline = x.find('a').find('h2').text
            ge_ = req.get(link,hades).text
            sop_ = bs(ge_,'lxml')
            content = sop_.find_all('div',class_='detail__body-text itp_bodycontent')
            for x in content:
                x = x.find_all('p')
                y  = [y.text for y in x ]
                content_ = ''.join(y).replace('\n', '').replace('ADVERTISEMENT','').replace('SCROLL TO RESUME CONTENT','')
                print(f'done[{a}] > {headline[0:10]}')
                a += 1
                with open('politik.csv','a')as file:
                    wr = csv.writer(file, delimiter=',')
                    wr.writerow([headline,date,link,content_])

# %%
scrape_detik(3)
# Out:
# done[1] > Dipayungi
# done[2] > Survei Lit
# done[3] > Survei Lit
# done[4] > Bawaslu Do
# done[5] > Jubir Part
# done[6] > PD dan PKS
# done[7] > Klaim Bran
# done[8] > Pileg 2024
# done[9] > Ternyata T
# done[10] > Mangku Pas
# done[11] > Andre Rosi
# done[12] > Petugas Pa
# done[13] > Gus Yahya
# done[14] > Suara NU J
# done[15] > Pemprov Se
# done[16] > PKS Rakern
# done[17] > PDIP Ungka
# done[18] > Mahfud Md

# %%
import pandas as pd
df = pd.read_csv('/content/politik.csv')
df
# Out:
#    Dipayungi AHY, Surya Paloh Tiba di Markas Demokrat Matangkan Koalisi  \
# 0   Survei Litbang Kompas: Ridwan Kamil Dominan di...
# 1   Survei Litbang Kompas: Ganjar 25,3%, Prabowo 1...
# 2   Bawaslu Dorong Ada Penerjemah bagi Disabilitas...
# 3   Jubir Partai Ummat Bicara Prabowo Sebagai 'Cad...
# 4   PD dan PKS Tak Iri Meski Elektabilitas NasDem ...
# 5   Klaim Brand Anies Dekat PKS, NasDem: Nggak Pen...
# 6   Pileg 2024, PKB Bidik 14 Kursi DPRD Kabupaten ...
# 7   Ternyata Tak Rahasia-rahasia Amat Kunjungan Bi...
# 8   Mangku Pastika-Gede Suardana Tampil 'Mesra' da...
# 9   Andre Rosiade Tegaskan Polarisasi Tak Diperluk...
# 10  Petugas Pantarlih Lumajang Coklit Data Pemilih...
# 11  Gus Yahya Tak Haramkan Warga NU Coblos PAN, PK...
# 12  Suara NU Jadi Rebutan di Pemilu 2024, Pengamat...
